# %% [markdown]
# Deep Learning with PyTorch: https://github.com/ytiam/tutorials/blob/example_notebooks/beginner_source/nlp/deep_learning_tutorial.py
# **************************
#
# Deep Learning Building Blocks: Affine maps, non-linearities and objectives
# ==========================================================================
#
# Deep learning consists of composing linearities with non-linearities in
# clever ways. The introduction of non-linearities allows for powerful
# models. In this section, we will play with these core components, make
# up an objective function, and see how the model is trained.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
torch.manual_seed(1)

# %%
lin = nn.Linear(5, 3)  # maps from R^5 to R^3, parameters A, b

# %%
lin
# Out:
# Linear(in_features=5, out_features=3, bias=True)

# %%
# data is 2x5.  A maps from 5 to 3... can we map "data" under A?
data = torch.randn(2, 5)

# %%
data
# Out:
# tensor([[-1.1948,  0.0250, -0.7627,  1.3969, -0.3245],
#         [ 0.2879,  1.0579,  0.9621,  0.3935,  1.1322]])

# %%
print(lin(data))
# Out:
# tensor([[ 0.1755, -0.3268, -0.5069],
#         [-0.6602,  0.2260,  0.1089]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# In pytorch, most non-linearities are in torch.functional (we have it imported as F)
# Note that non-linearites typically don't have parameters like affine maps do.
# That is, they don't have weights that are updated during training.

# %%
print(F.relu(lin(data)))
# Out:
# tensor([[0.1755, 0.0000, 0.0000],
#         [0.0000, 0.2260, 0.1089]], grad_fn=<ReluBackward0>)

# %%
# Softmax is also in torch.nn.functional
data = torch.randn(5)

# %%
data
# Out:
# tensor([-0.5404, -2.2102,  2.1130, -0.0040,  1.3800])

# %%
print(F.softmax(data, dim=0))
print(F.softmax(data, dim=0).sum())  # Sums to 1 because it is a distribution!
print(F.log_softmax(data, dim=0))  # theres also log_softmax
# Out:
# tensor([0.0418, 0.0079, 0.5936, 0.0715, 0.2852])
# tensor(1.)
# tensor([-3.1749, -4.8447, -0.5215, -2.6385, -1.2545])

# %%
# torch.log_(torch.tensor(0.2377))

# %%
######################################################################
# Example: Logistic Regression Bag-of-Words classifier
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Our model will map a sparse BoW representation to log probabilities over
# labels. We assign each word in the vocab an index. For example, say our
# entire vocab is two words "hello" and "world", with indices 0 and 1
# respectively. The BoW vector for the sentence "hello hello hello hello"
# is
#
# .. math::  \left[ 4, 0 \right]
#
# For "hello world world hello", it is
#
# .. math::  \left[ 2, 2 \right]
#
# etc. In general, it is
#
# .. math::  \left[ \text{Count}(\text{hello}), \text{Count}(\text{world}) \right]
#
# Denote this BOW vector as :math:`x`. The output of our network is:
#
# .. math::  \log \text{Softmax}(Ax + b)
#
# That is, we pass the input through an affine map and then do log
# softmax.
#

# %%
data = [("me gusta comer en la cafeteria".split(), "SPANISH"),
        ("Give it to me".split(), "ENGLISH"),
        ("No creo que sea una buena idea".split(), "SPANISH"),
        ("No it is not a good idea to get lost at sea".split(), "ENGLISH")]

# %%
test_data = [("Yo creo que si".split(), "SPANISH"),
             ("it is lost on me".split(), "ENGLISH")]

# %%
# word_to_ix maps each word in the vocab to a unique integer, which will be its
# index into the Bag of words vector
word_to_ix = {}
for sent, _ in data + test_data:
    for word in sent:
        if word not in word_to_ix:
            word_to_ix[word] = len(word_to_ix)
print(word_to_ix)
# Out:
# {'me': 0, 'gusta': 1, 'comer': 2, 'en': 3, 'la': 4, 'cafeteria': 5, 'Give': 6, 'it': 7, 'to': 8, 'No': 9, 'creo': 10, 'que': 11, 'sea': 12, 'una': 13, 'buena': 14, 'idea': 15, 'is': 16, 'not': 17, 'a': 18, 'good': 19, 'get': 20, 'lost': 21, 'at': 22, 'Yo': 23, 'si': 24, 'on': 25}

# %%
VOCAB_SIZE = len(word_to_ix)
NUM_LABELS = 2

# %%
# class BoWClassifier(nn.Module):  # inheriting from nn.Module!

#     def __init__(self, num_labels, vocab_size):
#         # calls the init function of nn.Module.  Dont get confused by syntax,
#         # just always do it in an nn.Module
#         super(BoWClassifier, self).__init__()

#         # Define the parameters that you will need.  In this case, we need A and b,
#         # the parameters of the affine mapping.
#         # Torch defines nn.Linear(), which provides the affine map.
#         # Make sure you understand why the input dimension is vocab_size
#         # and the output is num_labels!
#         self.linear = nn.Linear(vocab_size, num_labels)

#         # NOTE! The non-linearity log softmax does not have parameters! So we don't need
#         # to worry about that here

#     def forward(self, bow_vec):
#         # Pass the input through the linear layer,
#         # then pass that through log_softmax.
#         # Many non-linearities and other functions are in torch.nn.functional
#         return F.log_softmax(self.linear(bow_vec), dim=1)

# %%
class BoWClassifier_(nn.Module):

  def __init__(self,num_labels, vocab_size):
    super(BoWClassifier_,self).__init__()
    self.linear = nn.Linear(vocab_size,num_labels)

  def forward(self, bow_vec):
        return F.log_softmax(self.linear(bow_vec), dim=1)

# %%
def make_bow_vector(sentence, word_to_ix):
    vec = torch.zeros(len(word_to_ix))
    for word in sentence:
        vec[word_to_ix[word]] += 1
    return vec.view(1, -1)

# %%
model = BoWClassifier_(NUM_LABELS, VOCAB_SIZE)

# %%
model(make_bow_vector("Yo creo que si".split(),word_to_ix))
# Out:
# tensor([[-0.6866, -0.6998]], grad_fn=<LogSoftmaxBackward0>)

# %% [markdown]
# the model knows its parameters.  The first output below is A, the second is b. Whenever you assign a component to a class variable in the __init__ function of a module, which was done with the line
# # self.linear = nn.Linear(...)
# Then through some Python magic from the PyTorch devs, your module (in this case, BoWClassifier) will store knowledge of the nn.Linear's parameters

# %%
for param in model.parameters():
    print(param)
# Out:
# Parameter containing:
# tensor([[-0.1885, -0.0935,  0.1064, -0.0477,  0.1953,  0.1572, -0.0092, -0.1309,
#           0.1194,  0.0609, -0.1268,  0.1274,  0.1191,  0.1739, -0.1099, -0.0323,
#          -0.0038,  0.0286, -0.1488, -0.1392,  0.1067, -0.0460,  0.0958,  0.0112,
#           0.0644,  0.0431],
#         [ 0.0713,  0.0972, -0.1816,  0.0987, -0.1379, -0.1480,  0.0119, -0.0334,
#           0.1152, -0.1136, -0.1743,  0.1427, -0.0291,  0.1103,  0.0630, -0.1471,
#           0.0394,  0.0471, -0.1313, -0.0931,  0.0669,  0.0351, -0.0834, -0.0594,
#           0.1796, -0.0363]], requires_grad=True)
# Parameter containing:
# tensor([0.1106, 0.0849], requires_grad=True)

# %%
# To run the model, pass in a BoW vector
# Here we don't need to train, so the code is wrapped in torch.no_grad()
with torch.no_grad():
    sample = data[0]
    bow_vector = make_bow_vector(sample[0], word_to_ix)
    log_probs = model(bow_vector)
    print(log_probs)
# Out:
# tensor([[-0.5313, -0.8864]])

# %%
def make_target(label, label_to_ix):
    return torch.LongTensor([label_to_ix[label]])

# %%
# Which of the above values corresponds to the log probability of ENGLISH,
# and which to SPANISH? We never defined it, but we need to if we want to
# train the thing.

label_to_ix = {"SPANISH": 0, "ENGLISH": 1}

# %%
# Run on test data before we train, just to see a before-and-after
with torch.no_grad():
    for instance, label in test_data:
        bow_vec = make_bow_vector(instance, word_to_ix)
        log_probs = model(bow_vec)
        print(log_probs)
# Out:
# tensor([[-0.6866, -0.6998]])
# tensor([[-0.8991, -0.5225]])

# %%
# Print the matrix column corresponding to "creo"
print(next(model.parameters())[:, word_to_ix["creo"]])
# Out:
# tensor([-0.1268, -0.1743], grad_fn=<SelectBackward0>)

# %%
loss_function = nn.NLLLoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)

# %%
for epoch in range(200):
  for instance, label in data:
    model.zero_grad()

    bow_vec = make_bow_vector(instance, word_to_ix)
    target = make_target(label, label_to_ix)

    log_probs = model(bow_vec)
    loss = loss_function(log_probs, target)
    print('loss...', loss)
    loss.backward()
    optimizer.step()
# Out:
# loss... tensor(0.5313, grad_fn=<NllLossBackward0>)
# loss... tensor(0.6055, grad_fn=<NllLossBackward0>)
# loss... tensor(0.5221, grad_fn=<NllLossBackward0>)
# loss... tensor(0.9851, grad_fn=<NllLossBackward0>)
# loss... tensor(0.4010, grad_fn=<NllLossBackward0>)
# loss... tensor(0.3710, grad_fn=<NllLossBackward0>)
# loss... tensor(0.4625, grad_fn=<NllLossBackward0>)
# loss... tensor(0.3311, grad_fn=<NllLossBackward0>)
# loss... tensor(0.2968, grad_fn=<NllLossBackward0>)
# loss... tensor(0.2867, grad_fn=<NllLossBackward0>)
# loss... tensor(0.3413, grad_fn=<NllLossBackward0>)
# loss... tensor(0.1951, grad_fn=<NllLossBackward0>)
# loss... tensor(0.2316, grad_fn=<NllLossBackward0>)
# loss... tensor(0.2372, grad_fn=<NllLossBackward0>)
# loss... tensor(0.2588, grad_fn=<NllLossBackward0>)
# loss... tensor(0.1395, grad_fn=<NllLossBackward0>)
# loss... tensor(0.1891, grad_fn=<NllLossBackward0>)
# loss... tensor(0.2028, grad_fn=<NllLossBackward0>)
# loss... tensor(0.2055, grad_fn=<NllLossBackward0>)
# loss... tensor(0.1087, grad_fn=<NllLossBackward0>)
# loss... tensor(0.1597, grad_fn=<NllLossBackward0>)
# loss... tensor(0.1770, grad_fn=<NllLossBackward0>)
# loss... tensor(0.1694, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0889, grad_fn=<NllLossBackward0>)
# loss... tensor(0.1381, grad_fn=<NllLossBackward0>)
# loss... tensor(0.1570, grad_fn=<NllLossBackward0>)
# loss... tensor(0.1436, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0751, grad_fn=<NllLossBackward0>)
# loss... tensor(0.1217, grad_fn=<NllLossBackward0>)
# loss... tensor(0.1409, grad_fn=<NllLossBackward0>)
# loss... tensor(0.1245, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0650, grad_fn=<NllLossBackward0>)
# loss... tensor(0.1088, grad_fn=<NllLossBackward0>)
# loss... tensor(0.1278, grad_fn=<NllLossBackward0>)
# loss... tensor(0.1098, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0572, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0984, grad_fn=<NllLossBackward0>)
# loss... tensor(0.1169, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0981, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0510, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0898, grad_fn=<NllLossBackward0>)
# loss... tensor(0.1076, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0886, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0460, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0826, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0997, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0808, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0419, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0764, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0929, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0742, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0384, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0712, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0869, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0686, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0355, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0666, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0816, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0638, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0330, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0625, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0770, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0596, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0307, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0589, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0728, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0559, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0288, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0558, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0691, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0526, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0271, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0529, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0657, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0497, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0256, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0503, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0626, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0471, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0242, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0480, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0598, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0448, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0230, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0458, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0572, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0426, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0219, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0439, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0549, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0407, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0209, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0421, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0527, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0389, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0199, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0404, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0507, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0373, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0191, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0389, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0489, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0358, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0183, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0375, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0471, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0344, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0176, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0362, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0455, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0332, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0169, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0350, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0440, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0320, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0163, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0338, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0426, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0309, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0157, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0327, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0413, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0298, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0152, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0317, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0401, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0289, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0147, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0308, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0389, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0280, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0142, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0299, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0378, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0271, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0138, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0290, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0367, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0263, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0134, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0283, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0358, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0256, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0130, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0275, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0348, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0249, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0126, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0268, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0339, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0242, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0123, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0261, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0331, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0235, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0119, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0255, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0323, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0229, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0116, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0248, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0315, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0224, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0113, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0243, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0308, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0218, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0110, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0237, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0301, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0213, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0108, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0232, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0294, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0208, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0105, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0227, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0288, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0203, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0103, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0222, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0282, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0199, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0100, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0217, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0276, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0194, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0098, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0213, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0270, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0190, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0096, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0208, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0265, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0186, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0094, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0204, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0260, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0182, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0092, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0200, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0255, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0179, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0090, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0196, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0250, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0175, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0088, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0193, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0245, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0172, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0087, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0189, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0241, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0168, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0085, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0186, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0237, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0165, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0083, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0182, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0233, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0162, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0082, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0179, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0229, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0159, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0080, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0176, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0225, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0157, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0079, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0173, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0221, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0154, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0077, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0170, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0217, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0151, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0076, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0168, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0214, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0149, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0075, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0165, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0210, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0146, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0074, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0162, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0207, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0144, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0072, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0160, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0204, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0142, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0071, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0157, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0201, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0139, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0070, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0155, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0198, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0137, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0069, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0153, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0195, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0135, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0068, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0150, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0192, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0133, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0067, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0148, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0189, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0131, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0066, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0146, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0187, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0129, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0065, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0144, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0184, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0127, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0064, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0142, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0182, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0126, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0063, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0140, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0179, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0124, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0062, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0138, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0177, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0122, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0061, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0137, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0175, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0120, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0060, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0135, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0172, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0119, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0060, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0133, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0170, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0117, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0059, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0131, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0168, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0116, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0058, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0130, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0166, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0114, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0057, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0128, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0164, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0113, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0056, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0126, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0162, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0111, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0056, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0125, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0160, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0110, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0055, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0123, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0158, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0109, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0054, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0122, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0156, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0107, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0054, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0121, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0154, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0106, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0053, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0119, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0152, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0105, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0052, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0118, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0151, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0103, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0052, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0116, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0149, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0102, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0051, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0115, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0147, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0101, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0051, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0114, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0146, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0100, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0050, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0113, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0144, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0099, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0049, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0111, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0143, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0098, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0049, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0110, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0141, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0097, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0048, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0109, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0140, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0096, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0048, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0108, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0138, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0095, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0047, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0107, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0137, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0094, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0047, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0106, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0135, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0093, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0046, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0105, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0134, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0092, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0046, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0104, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0133, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0091, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0045, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0103, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0131, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0090, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0045, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0102, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0130, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0089, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0044, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0101, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0129, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0088, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0044, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0100, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0128, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0087, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0043, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0099, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0126, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0086, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0043, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0098, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0125, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0085, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0043, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0097, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0124, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0085, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0042, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0096, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0123, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0084, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0042, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0095, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0122, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0083, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0041, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0094, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0121, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0082, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0041, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0093, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0120, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0082, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0041, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0092, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0118, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0081, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0040, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0092, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0117, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0080, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0040, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0091, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0116, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0079, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0040, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0090, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0115, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0079, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0039, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0089, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0114, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0078, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0039, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0088, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0113, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0077, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0038, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0088, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0112, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0077, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0038, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0087, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0112, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0076, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0038, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0086, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0111, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0075, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0037, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0086, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0110, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0075, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0037, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0085, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0109, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0074, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0037, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0084, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0108, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0073, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0037, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0083, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0107, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0073, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0036, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0083, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0106, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0072, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0036, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0082, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0105, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0072, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0036, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0081, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0105, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0071, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0035, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0081, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0104, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0070, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0035, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0080, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0103, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0070, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0035, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0080, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0102, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0069, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0034, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0079, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0101, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0069, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0034, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0078, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0101, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0068, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0034, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0078, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0100, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0068, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0034, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0077, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0099, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0067, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0033, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0077, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0098, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0067, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0033, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0076, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0098, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0066, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0033, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0075, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0097, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0066, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0033, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0075, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0096, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0065, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0032, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0074, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0095, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0065, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0032, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0074, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0095, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0064, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0032, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0073, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0094, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0064, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0032, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0073, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0093, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0063, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0031, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0072, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0093, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0063, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0031, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0072, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0092, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0062, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0031, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0071, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0092, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0062, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0031, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0071, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0091, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0062, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0031, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0070, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0090, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0061, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0030, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0070, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0090, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0061, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0030, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0069, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0089, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0060, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0030, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0069, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0088, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0060, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0030, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0068, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0088, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0060, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0030, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0068, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0087, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0059, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0029, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0068, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0087, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0059, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0029, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0067, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0086, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0058, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0029, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0067, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0086, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0058, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0029, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0066, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0085, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0058, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0029, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0066, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0085, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0057, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0028, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0065, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0084, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0057, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0028, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0065, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0083, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0056, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0028, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0065, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0083, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0056, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0028, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0064, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0082, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0056, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0028, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0064, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0082, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0055, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0027, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0063, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0081, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0055, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0027, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0063, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0081, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0055, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0027, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0063, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0080, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0054, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0027, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0062, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0080, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0054, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0027, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0062, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0079, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0054, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0027, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0062, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0079, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0053, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0026, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0061, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0079, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0053, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0026, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0061, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0078, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0053, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0026, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0060, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0078, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0052, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0026, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0060, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0077, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0052, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0026, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0060, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0077, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0052, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0026, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0059, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0076, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0052, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0026, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0059, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0076, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0051, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0025, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0059, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0075, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0051, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0025, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0058, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0075, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0051, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0025, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0058, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0075, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0050, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0025, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0058, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0074, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0050, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0025, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0057, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0074, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0050, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0025, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0057, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0073, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0049, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0025, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0057, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0073, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0049, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0024, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0056, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0073, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0049, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0024, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0056, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0072, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0049, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0024, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0056, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0072, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0048, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0024, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0056, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0071, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0048, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0024, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0055, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0071, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0048, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0024, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0055, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0071, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0048, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0024, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0055, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0070, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0047, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0023, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0054, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0070, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0047, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0023, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0054, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0070, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0047, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0023, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0054, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0069, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0047, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0023, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0054, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0069, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0046, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0023, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0053, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0068, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0046, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0023, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0053, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0068, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0046, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0023, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0053, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0068, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0046, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0023, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0052, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0067, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0045, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0022, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0052, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0067, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0045, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0022, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0052, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0067, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0045, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0022, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0052, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0066, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0045, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0022, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0051, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0066, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0044, grad_fn=<NllLossBackward0>)
# loss... tensor(0.0022, grad_fn=<NllLossBackward0>)

# %%
with torch.no_grad():
    for instance, label in test_data:
        bow_vec = make_bow_vector(instance, word_to_ix)
        log_probs = model(bow_vec)
        print(log_probs)
# Out:
# tensor([[-0.1164, -2.2087]])
# tensor([[-3.3730, -0.0349]])

# %%
print(next(model.parameters())[:, word_to_ix["creo"]])
# Out:
# tensor([ 0.0245, -0.0899], grad_fn=<SelectBackward0>)
